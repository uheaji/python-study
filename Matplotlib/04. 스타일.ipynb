# %% [markdown]
# ## 4. 스타일

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
matplotlib.rcParams['font.size'] = 15 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자기 깨지는 현상 해결

x =[1, 2, 3]
y =[2, 6, 4]

# %% [markdown]
# ### ◽ 선 두께

# %%
plt.plot(x, y)

# %%
# 선을 두껍게
plt.plot(x, y, linewidth=5)

# %% [markdown]
# ***

# %% [markdown]
# ### ◽ 마커
#
# 👀 마커 종류
# > [https://matplotlib.org/stable/api/markers_api.html](https://matplotlib.org/stable/api/markers_api.html)

# %%
# 마커 추가
plt.plot(x, y, marker='o')

# %%
# 선이 사라짐
plt.plot(x, y,  marker='o', linestyle='None')

# %%
# 마커가 삼각형
plt.plot(x, y,  marker='v', markersize=10)

# %%
# 마커가 x
plt.plot(x, y,  marker='X', markersize=10)

# %%
# 마커 테두리색상 변경
plt.plot(x, y,  marker='o', markersize=20, markeredgecolor='red')

# %%
# 마커 색상 변경
plt.plot(x, y,  marker='o', markersize=20, markeredgecolor='red', markerfacecolor='yellow')

# %% [markdown]
# ***
# ### ◽ 선 스타일
#
# 👀 선 스타일 종류
# > [https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html](https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html)

# %%
# 선을 점선으로 변경
plt.plot(x, y, linestyle = ':')

# %%
# 선을 --으로 변경
plt.plot(x, y, linestyle = '--')

# %%
# 선을 -.-.-.으로 변경
plt.plot(x, y, linestyle = '-.')

# %% [markdown]
# ***
# ### ◽ 선 색깔
#
# 👀 matplotlib 색 종류
# >[https://matplotlib.org/stable/gallery/color/named_colors.html](https://matplotlib.org/stable/gallery/color/named_colors.html)

# %%
plt.plot(x, y, color='pink')

# %%
plt.plot(x, y, color='#ff0000')

# %%
plt.plot(x, y, color='b')

# %%
plt.plot(x, y, color='g')

# %% [markdown]
# ***
# ### ◽ 포맷

# %%
plt.plot(x, y, 'ro--') # color, marker, linestyle

# %%
plt.plot(x, y, 'bv:') # color, marker, linestyle

# %%
plt.plot(x, y, 'go') # color, marker, linestlye은 없음
plt.plot(x, y, color='g', marker='o', linestyle='none') # color, marker, linestlye은 없음

# %% [markdown]
# ***
# ### ◽ 축약어
#
# 👀 축약어
# >[https://matplotlib.org/2.0.2/api/pyplot_api.html](https://matplotlib.org/2.0.2/api/pyplot_api.html)

# %%
plt.plot(x, y, marker='o', mfc='red', ms=10, mec='blue', ls=':')

# %% [markdown]
# ***
# ### ◽ 투명도

# %%
plt.plot(x, y, marker='o', mfc='red', ms=10, alpha=0.3) # alpha : 투명도(0~1)

# %% [markdown]
# ***
# ### ◽ 그래프 크기

# %%
plt.figure(figsize=(10,5))
plt.plot(x, y)

# %%
plt.figure(figsize=(5,10))
plt.plot(x, y)

# %%
plt.figure(figsize=(10,5), dpi=100) # dots per inch : 확대
plt.plot(x, y)

# %% [markdown]
# ***
# ### ◽ 배경색

# %%
plt.figure(facecolor='yellow')
plt.plot(x, y)

# %%
plt.figure(facecolor='#a1c3ff')
plt.plot(x, y)
